# %%
'''

Name: Jose Garcia
Class: CSC106
HW#: 1 week 7
QN: 1
Date: 10/27/2023

'''

# %%
import time

from termcolor import colored

display = [1,2,3,4,5,6,7,8]
i1 = 1
while i1 < 4:
    i = 1
    while i < 17:
        i += 1
        for i in range(0, 8):
            display[i] = colored(' ', 'black', attrs=['reverse', 'blink'])
            if(i == 2) and (i1 == 1):
                display[0] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 2) and (i1 == 2):
                continue
            elif(i == 2) and (i1 == 3):
                continue
            elif(i == 3):
                display[1] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 4):
                display[2] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 5):
                display[3] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 6):
                display[4] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 7):
                display[5] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 8):
                display[6] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 9):
                display[7] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 10):
                display[6] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 11):
                display[5] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 12):
                display[4] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 13):
                display[3] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 14):
                display[2] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 15):
                display[1] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 16):
                display[0] = colored('*', 'red', attrs=['reverse', 'blink'])
            elif(i == 17):
                continue
        time.sleep(0.5)
        print(display[0],display[1],display[2],display[3],display[4],display[5],display[6],display[7])
    i1 += 1
# Out:
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# ...
